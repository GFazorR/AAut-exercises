# %%
import pandas as pd
import numpy as np

clusters_3_df = pd.read_csv("../Datasets/3-clusters.csv", header=1)
# display(clusters_3_df)
dbscan_df = pd.read_csv("../Datasets/dataset-DBSCAN.csv", header=1)
# display(dbscan_df)
cure_df = pd.read_csv("../Datasets/CURE-complete.csv", header=1)
# display(cure_df)
# Out:
#          x    y
# 0        9  480
# 1        9  479
# 2        9  478
# 3        9  477
# 4        9  467
# ...    ...  ...
# 86553  435  168
# 86554  435  164
# 86555  436  292
# 86556  436  172
# 86557  436  171
#
# [86558 rows x 2 columns]

# %%
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(8, 8))
ax = fig.add_subplot(111)
fig.subplots_adjust(top=1)
ax.set_title("Dataset n.1 of data points")
ax.set_xlabel(clusters_3_df.columns[0])
ax.set_ylabel(clusters_3_df.columns[1])

plt.plot(clusters_3_df["x"], clusters_3_df["y"], ". ", markersize=1)

plt.show()

# %%
fig = plt.figure(figsize=(8, 8))
ax = fig.add_subplot(111)
fig.subplots_adjust(top=1)
ax.set_title("Dataset n.1 of data points")
ax.set_xlabel(dbscan_df.columns[0])
ax.set_ylabel(dbscan_df.columns[1])

plt.plot(dbscan_df["x"], dbscan_df["y"], ". ", markersize=1)

plt.show()

# %%
fig = plt.figure(figsize=(8, 8))
ax = fig.add_subplot(111)
fig.subplots_adjust(top=1)
ax.set_title("Dataset n.1 of data points")
ax.set_xlabel(cure_df.columns[0])
ax.set_ylabel(cure_df.columns[1])

plt.plot(cure_df["x"], cure_df["y"], ". ", markersize=1)

plt.show()

# %%
from sklearn.cluster import KMeans

k = 3
kmc_1 = KMeans(n_clusters=k, random_state=0).fit(clusters_3_df.to_numpy())

for i in range(clusters_3_df.shape[0]):
    print(f"Example n.{i}=({clusters_3_df['x'][i]},{clusters_3_df['y'][i]})")
    print(f"in cluster n.{kmc_1.labels_[i]}")
# Out:
# Example n.0=(10,10)
# in cluster n.0
# Example n.1=(11,11)
# in cluster n.0
# Example n.2=(12,12)
# in cluster n.0
# Example n.3=(13,13)
# in cluster n.0
# Example n.4=(14,14)
# in cluster n.0
# Example n.5=(15,15)
# in cluster n.0
# Example n.6=(16,16)
# in cluster n.0
# Example n.7=(17,17)
# in cluster n.0
# Example n.8=(18,18)
# in cluster n.0
# Example n.9=(19,19)
# in cluster n.0
# Example n.10=(20,20)
# in cluster n.0
# Example n.11=(21,21)
# in cluster n.0
# Example n.12=(22,22)
# in cluster n.0
# Example n.13=(23,23)
# in cluster n.0
# Example n.14=(24,24)
# in cluster n.0
# Example n.15=(25,25)
# in cluster n.0
# Example n.16=(26,26)
# in cluster n.0
# Example n.17=(27,27)
# in cluster n.0
# Example n.18=(28,28)
# in cluster n.0
# Example n.19=(29,29)
# in cluster n.0
# Example n.20=(30,30)
# in cluster n.0
# Example n.21=(31,31)
# in cluster n.0
# Example n.22=(32,32)
# in cluster n.0
# Example n.23=(33,33)
# in cluster n.0
# Example n.24=(34,34)
# in cluster n.0
# ...

# %%
fig = plt.figure(figsize=(8, 8))
ax = fig.add_subplot(111)
fig.subplots_adjust(top=1)
ax.set_title("Dataset n.1 of data points")
ax.set_xlabel(clusters_3_df.columns[0])
ax.set_ylabel(clusters_3_df.columns[1])

color = ['b', 'g', 'r', 'c', 'm', 'y', 'k', 'w']

for clu in range (k):
    data_list_x = [clusters_3_df["x"][i] for i in range(clusters_3_df.shape[0]) if kmc_1.labels_[i] == clu]
    data_list_y = [clusters_3_df["y"][i] for i in range(clusters_3_df.shape[0]) if kmc_1.labels_[i] == clu]
    plt.scatter(data_list_x, data_list_y, s=2, edgecolors='none', c=color[clu], alpha=0.5)

plt.show()

# %%
k = 7
kmc_2 = KMeans(n_clusters=k, random_state=0).fit(cure_df.to_numpy())

# for i in range(cure_df.shape[0]):
#     print(f"Example n.{i}=({cure_df['x'][i]},{cure_df['y'][i]})")
#     print(f"in cluster n.{kmc_2.labels_[i]}")

# %%
fig = plt.figure(figsize=(8, 8))
ax = fig.add_subplot(111)
fig.subplots_adjust(top=1)
ax.set_title("Dataset n.1 of data points")
ax.set_xlabel(cure_df.columns[0])
ax.set_ylabel(cure_df.columns[1])

color = ['b', 'g', 'r', 'c', 'm', 'y', 'k', 'w']

for clu in range (k):
    data_list_x = [cure_df["x"][i] for i in range(cure_df.shape[0]) if kmc_2.labels_[i] == clu]
    data_list_y = [cure_df["y"][i] for i in range(cure_df.shape[0]) if kmc_2.labels_[i] == clu]
    plt.scatter(data_list_x, data_list_y, s=2, edgecolors='none', c=color[clu], alpha=0.5)

plt.show()
